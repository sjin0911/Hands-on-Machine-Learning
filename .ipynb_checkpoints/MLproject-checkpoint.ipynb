# %%
# !pip install kaggle --upgrade
# Out:
# Collecting kaggle
#   Downloading kaggle-1.6.14.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (1.16.0)
# Collecting certifi>=2023.7.22 (from kaggle)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-slugify in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (1.26.7)
# Requirement already satisfied: bleach in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from kaggle) (4.0.0)
# Requirement already satisfied: packaging in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from bleach->kaggle) (21.0)
# Requirement already satisfied: webencodings in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from requests->kaggle) (3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->kaggle) (3.0.4)
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.6.14-py3-none-any.whl size=105124 sha256=b43ba9a8bd483e77ca6b1922d627f7dd7de3daaa3bd0d9cf9c7a8c19379473ad
#   Stored in directory: /Users/yoonsjin/Library/Caches/pip/wheels/23/f1/ec/3f9079ada5cc1218f9accf05ccca9f0a57533191e49d76e3f6
# Successfully built kaggle
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: certifi, kaggle
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:
#       Successfully uninstalled certifi-2021.10.8
# Successfully installed certifi-2024.2.2 kaggle-1.6.14

# %%
# !pip show kaggle
# Out:
# Name: kaggle
# Version: 1.6.14
# Summary: Kaggle API
# Home-page: https://github.com/Kaggle/kaggle-api
# Author: Kaggle
# Author-email: support@kaggle.com
# License: Apache 2.0
# Location: /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages
# Requires: bleach, certifi, python-dateutil, python-slugify, requests, six, tqdm, urllib3
# Required-by:

# %%
# !kaggle config view
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/yoonsjin/.kaggle/kaggle.json'
# Configuration values from /Users/yoonsjin/.kaggle
# - username: seojin0911
# - path: None
# - proxy: None
# - competition: None

# %%
# !pip show kaggle
# Out:
# Name: kaggle
# Version: 1.6.14
# Summary: Kaggle API
# Home-page: https://github.com/Kaggle/kaggle-api
# Author: Kaggle
# Author-email: support@kaggle.com
# License: Apache 2.0
# Location: /Users/yoonsjin/opt/anaconda3/lib/python3.9/site-packages
# Requires: bleach, certifi, python-dateutil, python-slugify, requests, six, tqdm, urllib3
# Required-by:

# %%
# !kaggle datasets download -d edumagalhaes/quality-prediction-in-a-mining-process
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/yoonsjin/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/edumagalhaes/quality-prediction-in-a-mining-process
# License(s): CC0-1.0
# Downloading quality-prediction-in-a-mining-process.zip to /Users/yoonsjin/.Trash/MLproject
# 100%|██████████████████████████████████████| 50.9M/50.9M [00:07<00:00, 8.14MB/s]
# 100%|██████████████████████████████████████| 50.9M/50.9M [00:07<00:00, 7.24MB/s]

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import shutil

filename='quality-prediction-in-a-mining-process.zip'
extrac_dir=''
data=pd.read_csv("MiningProcess_Flotation_Plant_Database.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/6x/4ry3jzt90r9dc3l60wtfp3fc0000gn/T/ipykernel_12949/2856441351.py in <module>
#       7 def load_data():
#       8     t
# ----> 9 data=pd.read_csv("MiningProcess_Flotation_Plant_Database.csv")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MiningProcess_Flotation_Plant_Database.csv'

# %%
for col in data.columns:
    if col!='date':
        data[col]=data[col].str.replace(',','')
        data[col]=data[col].astype('float64')

# %%
data.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00        552.0         1698.0     301953.0    557434.0
# 1  2017-03-10 01:00:00        552.0         1698.0     302441.0    563965.0
# 2  2017-03-10 01:00:00        552.0         1698.0     304346.0    568054.0
# 3  2017-03-10 01:00:00        552.0         1698.0     304736.0    568665.0
# 4  2017-03-10 01:00:00        552.0         1698.0     303369.0    558167.0
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 
flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                  7.374530e+05                  7.374530e+05
# mean                   3.549008e+10                  4.402292e+10
# std                    2.617307e+11                  2.955984e+11
# min                    1.990000e+02                  1.940000e+02
# 25%                    2.500530e+05                  2.492920e+05
# 50%                    2.992670e+05                  2.953130e+05
# 75%                    3.001460e+05                  3.006830e+05
# max                    3.724426e+12                  3.690073e+12
#
#        Flotation Column 03 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                  7.374530e+05  ...                  7.374530e+05
# mean                   4.028435e+10  ...                  2.475333e+10
# std                    2.896449e+11  ...                  2.640849e+11
# min                    1.990000e+02  ...                  2.400000e+02
# 25%                    2.499290e+05  ...                  2.505780e+05
# 50%                    2.985210e+05  ...                  2.985280e+05
# 75%                    3.003670e+05  ...                  3.016210e+05
# max                    3.620642e+12  ...                  3.699183e+12
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count               7.374530e+05               7.374530e+05
# mean                4.358469e+11               5.218964e+11
# std                 1.795397e+12               1.871729e+12
# min                 1.630000e+02               2.260000e+02
# 25%                 4.043530e+05               4.265630e+05
# 50%                 4.799190e+05               4.919270e+05
# 75%                 5.919140e+05               5.971840e+05
# max                 8.622205e+12               8.284389e+12
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count               7.374530e+05               7.374530e+05
# mean                6.399874e+11               2.280960e+11
# std                 2.210399e+12               1.090460e+12
# min                 1.300000e+02               1.750000e+02
# 25%                 4.015530e+05               3.470960e+05
# 50%                 4.804950e+05               4.053970e+05
# 75%                 6.005830e+05               4.861880e+05
# max                 8.868202e+12               6.800200e+12
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count               7.374530e+05               7.374530e+05
# mean                2.101705e+11               2.204856e+11
# std                 1.099108e+12               1.109635e+12
# min                 2.510000e+02               1.650000e+02
# 25%                 3.486930e+05               3.463910e+05
# 50%                 4.006120e+05               4.080160e+05
# 75%                 4.787370e+05               4.895760e+05
# max                 6.755715e+12               6.986233e+12
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count               7.374530e+05        7.374530e+05          7.374530e+05
# mean                1.990718e+11        3.028853e+10          2.751787e+09
# std                 1.025817e+12        1.346026e+11          1.029048e+10
# min                 2.350000e+02        6.300000e+01          1.000000e+00
# 25%                 3.462670e+05        6.421000e+03          1.310000e+02
# 50%                 4.025630e+05        6.522000e+03          1.860000e+02
# 75%                 4.737560e+05        6.595000e+03          2.940000e+02
# max                 6.596583e+12        6.608867e+11          5.529797e+10
#
# [8 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
data.hist(bins=100, figsize=(20,20))
plt.show()

# %%
import numpy as np

#랜덤으로 어떤 샘플을 선택해서 데이터셋의 20% 정도를 떼어놓는 함수
def shuffle_and_split_data(data, test_ratio):
    shuffled_indices=np.random.permutation(len(data))
    test_set_size=int(len(data)*test_ratio)
    test_indices=shuffled_indices[:test_set_size]
    train_indices=shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
#데이터의 15퍼센트를 test
train_set, test_set=shuffle_and_split_data(data,0.15)
